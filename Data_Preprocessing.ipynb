# %%
#### first step of ML & DS is Data_preprocessing,after that only remaining things...

#Rule_1: "missing value" should not be in dataset.(Ex: null,NaN..)
#Rule_2: "outlier's" should not be present in dataset.


#### options for replacing "missing values" in Rule_1:

#1.delete the entire row which have missing values..
#2.Replace the missing values using central tendency(mean,median,mode)
#3.respective to the problem statement in dataset, have to replace the missing values.
#4.consider this as semi-supervised and create a model using "ML" , so that we can predict the missing values and replace it.

# %%
import warnings
warnings.filterwarnings('ignore') # To ignore warnings because you are learning from 2022 video records may be you are using old version features...

# %%
import pandas as pd

# %%
dataset=pd.read_csv("placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()                    # to view the null(or)NaN values in dataset
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.isna().sum()                            # isnull() and isna() both gives same output....
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # 3.respective to the problem statement in dataset,have to replace the missing values.

# %%
dataset["salary"].fillna(0,inplace=True)             # "inplace" is used for directly updating in original dataset....
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#### THE above--- "3rd" --- option is the suitable option for this dataset to replace the missing value......####

# %%
dataset.isnull().sum()                      # to view the null(or)NaN values in dataset
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # 1.delete the entire row which have missing values..

# %%
dataset.dropna(inplace=True)                  # for deleting each and every null value rows in dataset
#dataset

# %% [markdown]
# # 2.Replace the missing values using central tendency(mean,median,mode)

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)
#dataset

# %%
dataset["salary"].fillna(dataset["salary"].median(),inplace=True) 
#dataset

# %%
dataset["salary"].fillna(dataset["salary"].mode(),inplace=True) 
#dataset

# %%
#### below we are using automatic replacement of overall columns in a dataset using central tendencys  by "sklearn" ####

# %%
#### we can't do automatic replacement for Qual(catogorical) columns in a dataset using central tendency so we are seperating Qual and Quan.......


def QualQuan(dataset): # if you mentioned any variable in open paranthisis only, you can use the class in future...

    Qual=[]
    Quan=[]
    
    for columnName in dataset.columns:
        
        if(dataset[columnName].dtypes=="O"):
            #print("Qual")
            Qual.append(columnName)                ##### Function created #####
            
            
        else:                              
            #print("Quan")
            Quan.append(columnName)
            
    return Qual,Quan

# %%
Qual,Quan= QualQuan(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
imp.fit(dataset[Quan])
df=imp.transform(dataset[Quan])
df
# Out:
# array([[1.00000000e+00, 6.70000000e+01, 9.10000000e+01, ...,
#         5.50000000e+01, 5.88000000e+01, 2.70000000e+05],
#        [2.00000000e+00, 7.93300000e+01, 7.83300000e+01, ...,
#         8.65000000e+01, 6.62800000e+01, 2.00000000e+05],
#        [3.00000000e+00, 6.50000000e+01, 6.80000000e+01, ...,
#         7.50000000e+01, 5.78000000e+01, 2.50000000e+05],
#        ...,
#        [2.13000000e+02, 6.70000000e+01, 6.70000000e+01, ...,
#         5.90000000e+01, 6.97200000e+01, 2.95000000e+05],
#        [2.14000000e+02, 7.40000000e+01, 6.60000000e+01, ...,
#         7.00000000e+01, 6.02300000e+01, 2.04000000e+05],
#        [2.15000000e+02, 6.20000000e+01, 5.80000000e+01, ...,
#         8.90000000e+01, 6.02200000e+01, 2.88655405e+05]])

# %%
df=pd.DataFrame(df,columns=Quan)
df
#df.isnull().sum()
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000
# ..     ...    ...    ...       ...      ...    ...            ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405
#
# [215 rows x 7 columns]

# %% [markdown]
# # 4.consider this as semi-supervised and create a model using "ML" , so that we can predict the missing values and replace it.

# %%
#### Mostly we won't go for this option because it comes under ML and instead of this we have central tendency in "Data Science"...####

# %% [markdown]
# # Genral Notes:

# %%
# for overall replacement of missing values in categorical(Qual) columns , we can use central tedency("Mode") method in DS.

# %% [markdown]
# # Merging 2 csv file

# %%
numi = df
numi
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000
# ..     ...    ...    ...       ...      ...    ...            ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405
#
# [215 rows x 7 columns]

# %%
cata = dataset[Qual]
cata
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 214      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
two=[numi,cata]
merged_file= pd.concat(two,axis=1)      # axis=1 indicates column wise merge....
merged_file
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
merged_file.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %% [markdown]
# # saving a preprocessed_file

# %%
merged_file.to_csv("pre_placement.csv",index=False) # to avoid duplicate(double index)--- index=false...
